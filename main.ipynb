# %%
import pandas as pd
import re
attacks = pd.read_csv("input/attacks.csv",encoding='utf-8')

# %%
attacks['Country'].value_counts().head(30)
# Out:
# USA                 2229
# AUSTRALIA           1338
# SOUTH AFRICA         579
# PAPUA NEW GUINEA     134
# NEW ZEALAND          128
# BRAZIL               112
# BAHAMAS              109
# MEXICO                89
# ITALY                 71
# FIJI                  62
# PHILIPPINES           61
# REUNION               60
# NEW CALEDONIA         53
# CUBA                  46
# MOZAMBIQUE            45
# SPAIN                 44
# INDIA                 40
# EGYPT                 38
# JAPAN                 34
# CROATIA               34
# PANAMA                32
# SOLOMON ISLANDS       30
# IRAN                  29
# JAMAICA               27
# FRENCH POLYNESIA      25
# GREECE                25
# HONG KONG             24
# INDONESIA             23
# ENGLAND               23
# COSTA RICA            17
# Name: Country, dtype: int64

# %%
attacks['Area Total']=attacks['Area'].groupby(attacks['Area']).transform('count')

# %%
def get_month(date):
    try:
        
        month = re.findall(r'jan|feb|mar|apr|may|jun|jul|aug|sep|oct|nov|dec|summer|fall|', date, flags=re.IGNORECASE) 
        month =list(filter(None, month))
        if len(month):
            return month[0].lower()
        return None
    except TypeError:
        return None


attacks['Month']= attacks['Date'].map(get_month)

# %%
def get_season(month):
    northern_summer = ['apr','may','jun','jul','aug','sep','summer']
    northern_winter = ['jan','feb','mar','oct','nov','dec', 'fall']

    if month in northern_summer:
        return 'northern_summer'
    if month in northern_winter:
        return 'northern_winter'
    
attacks['Season']= attacks['Month'].map(get_season)

# %%
def get_data_by_country(df,country):
    return df[df['Country']==country]

# %%
attacks_by_country = get_data_by_country(attacks,'USA')

attacks_by_country = attacks_by_country.groupby('Month')['Area'].count()
attacks_by_country
# Out:
# Month
# apr       157
# aug       325
# dec        64
# fall        3
# feb        57
# jan        51
# jul       358
# jun       243
# mar        97
# may       155
# nov       118
# oct       206
# sep       299
# summer      5
# Name: Area, dtype: int64

# %%
USA_ATTACKS.groupby('Season').count()
# Out:
#                  Case Number  Date  Year  Type  Country  Area  Location  \
# Season
# northern_summer           11    11    11    11       11     8        11
# northern_winter            9     9     9     9        9     9         9
#
#                  Activity  Name  Sex   ...  pdf  href formula  href  \
# Season                                 ...
# northern_summer        10     8    10  ...   11            11    11
# northern_winter         8     7     6  ...    9             9     9
#
#                  Case Number.1  Case Number.2  original order  Unnamed: 22     \
# Season
# northern_summer             11             11              11            0  0
# northern_winter              9              9               9            0  0
#
#                  Area Total  Month
# Season
# northern_summer           8     11
# northern_winter           9      9
#
# [2 rows x 26 columns]

# %%
def fix_species_name(row):
    try:
        shark_type = re.search(r'^(.*) shark', row['Species '])
        if(shark_type):          
            return shark_type.group(1).lower()
    except TypeError as e:
        return row['Species ']
    return

# %%
attacks['Shark type']= attacks.apply(fix_species_name, axis='columns')

# %%
attacks.value_counts('Shark type').reset_index()
# Out:
#                           Shark type    0
# 0                              white  428
# 1                              tiger  233
# 2                               bull  125
# 3                      bronze whaler   56
# 4                              nurse   49
# ..                               ...  ...
# 745              8' great hammerhead    1
# 746  8' bull shark or caribbean reef    1
# 747                                8    1
# 748              76 cm [2.5'] carpet    1
# 749                          "gummy"    1
#
# [750 rows x 2 columns]

# %%
def count_species(df):
        return df['Shark type'].value_counts()

# %%
USA_ATTACKS
# Out:
#      Case Number                                               Date    Year  \
# 15    2018.05.12                                        12-May-2018  2018.0
# 24    2018.04.22                                        22-Apr-2018  2018.0
# 34    2018.04.03                                        03-Apr-2018  2018.0
# 39    2018.02.24                                        24-Feb-2018  2018.0
# 76    2017.10.01                                        01-Oct-2017  2017.0
# ...          ...                                                ...     ...
# 6281     ND.0021                                            No date     0.0
# 6285     ND.0017                                        Before 1921     0.0
# 6286     ND.0016                                        Before 1921     0.0
# 6289     ND.0013  No date (3 days after preceding incident) & pr...     0.0
# 6290     ND.0012                                 Before 19-Jul-1913     0.0
#
#             Type       Country                   Area  \
# 15    Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 24    Unprovoked  SOUTH AFRICA  Western Cape Province
# 34    Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 39    Unprovoked  SOUTH AFRICA          KwaZulu-Natal
# 76       Invalid  SOUTH AFRICA  Western Cape Province
# ...          ...           ...                    ...
# 6281  Unprovoked  SOUTH AFRICA          KwaZulu-Natal
# 6285  Unprovoked  SOUTH AFRICA          KwaZulu-Natal
# 6286  Unprovoked  SOUTH AFRICA          KwaZulu-Natal
# 6289  Unprovoked  SOUTH AFRICA          KwaZulu-Natal
# 6290  Unprovoked  SOUTH AFRICA          KwaZulu-Natal
#
#                             Location  \
# 15         Nahoon Beach, East London
# 24    Robberg Beach, Plettenberg Bay
# 34                   St. Francis Bay
# 39                            Durban
# 76                       Dyer Island
# ...                              ...
# 6281                         Durban
# 6285                         Durban
# 6286                          Durban
# 6289                          Durban
# 6290                          Durban
#
#                                                Activity                Name  \
# 15                                              Surfing                male
# 24                                        Paddle-skiing                male
# 34                                              Surfing        Ross Spowart
# 39                                         Scuba Diving         Elton Polly
# 76                                         Scuba Diving        Bradley Fick
# ...                                                 ...                 ...
# 6281  Swimming in pool formed by construction of a w...          Indian boy
# 6285        Crew swimming alongside their anchored ship                male
# 6286                                 4 men were bathing                male
# 6289                                            Fishing  a native fisherman
# 6290                                             Wading    a young Scotsman
#
#      Sex   ...                                               href  \
# 15      M  ...  http://sharkattackfile.net/spreadsheets/pdf_di...
# 24      M  ...  http://sharkattackfile.net/spreadsheets/pdf_di...
# 34      M  ...  http://sharkattackfile.net/spreadsheets/pdf_di...
# 39      M  ...  http://sharkattackfile.net/spreadsheets/pdf_di...
# 76      M  ...  http://sharkattackfile.net/spreadsheets/pdf_di...
# ...   ...  ...                                                ...
# 6281    M  ...  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6285    M  ...  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6286    M  ...  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6289    M  ...  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6290    M  ...  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#      Case Number.1 Case Number.2 original order Unnamed: 22      Area Total  \
# 15      2018.05.12    2018.05.12         6288.0         NaN  NaN      160.0
# 24      2018.04.22    2018.04.22         6279.0         NaN  NaN      195.0
# 34      2018.04.02    2018.04.03         6269.0         NaN  NaN      160.0
# 39      2018.02.24    2018.02.24         6264.0         NaN  NaN      213.0
# 76      2017.10.01    2017.10.01         6227.0         NaN  NaN      195.0
# ...            ...           ...            ...         ...  ...        ...
# 6281       ND.0021       ND.0021           22.0         NaN  NaN      213.0
# 6285       ND.0017       ND.0017           18.0         NaN  NaN      213.0
# 6286       ND.0016       ND.0016           17.0         NaN  NaN      213.0
# 6289       ND.0013       ND.0013           14.0         NaN  NaN      213.0
# 6290       ND.0012       ND.0012           13.0         NaN  NaN      213.0
#
#      Month           Season Shark type
# 15     may  northern_summer        NaN
# 24     apr  northern_summer      white
# 34     apr  northern_summer      white
# 39     feb  northern_winter   blacktip
# 76     oct  northern_winter       None
# ...    ...              ...        ...
# 6281  None             None        NaN
# 6285  None             None        NaN
# 6286  None             None        NaN
# 6289   jul  northern_summer        NaN
# 6290   jul  northern_summer        NaN
#
# [579 rows x 28 columns]

# %%
attack_counts = USA_ATTACKS.groupby('Area').size().reset_index(name='counts').sort_values(by='counts',ascending=False)
attack_counts
# Out:
#                                                 Area  counts
# 3                                      KwaZulu-Natal     213
# 7                              Western Cape Province     195
# 1                              Eastern Cape Province     160
# 0                             Eastern Cape  Province       1
# 2                                   Eastern Province       1
# 4  KwaZulu-Natal between Port Edward and Port St ...       1
# 5                               South Atlantic Ocean       1
# 6                                          Transvaal       1
# 8                                   Western Province       1

# %%
 USA_ATTACKS.groupby(['Area','Season']).apply(count_species)
# Out:
# Area                   Season
# Eastern Cape Province  northern_summer  white                                                  11
#                                         raggedtooth                                             6
#                                         4 m [13'] white                                         3
#                                         2.4 m [8'] white                                        2
#                                         2.5 m [8.25'] white                                     2
#                                                                                                ..
# Western Cape Province  northern_winter  mako                                                    1
#                                         1.5 m [5']                                              1
#                                         1.5 m to 1.8 m [5' to 6']                               1
#                                         3.5 m [11.5'], 510-kg [1125-lb] hooked & shot white     1
# Western Province       northern_winter  white                                                   1
# Name: Shark type, Length: 174, dtype: int64

# %%
by_shark_type= USA_ATTACKS.groupby(['Area','Area Total','Season']).apply(count_species).reset_index().sort_values(by=["Area Total",'Shark type'],ascending=False)
by_shark_type
# Out:
#                                                   Area  Area Total  \
# 63                                       KwaZulu-Natal       213.0
# 64                                       KwaZulu-Natal       213.0
# 65                                       KwaZulu-Natal       213.0
# 49                                       KwaZulu-Natal       213.0
# 66                                       KwaZulu-Natal       213.0
# ..                                                 ...         ...
# 47                               Eastern Cape Province       160.0
# 48                               Eastern Cape Province       160.0
# 173                                   Western Province         5.0
# 109  KwaZulu-Natal between Port Edward and Port St ...         1.0
# 110                                          Transvaal         1.0
#
#               Season                            level_3  Shark type
# 63   northern_winter                              white          15
# 64   northern_winter                            zambesi           7
# 65   northern_winter                        raggedtooth           5
# 49   northern_summer                              white           4
# 66   northern_winter                              tiger           4
# ..               ...                                ...         ...
# 47   northern_winter                  2.1 m [7'], 90-kg           1
# 48   northern_winter         1.5 m to 2 m [5' to 6.75']           1
# 173  northern_winter                              white           1
# 109  northern_summer  1.5 to 2.5 m [5' to 8.25'] copper           1
# 110  northern_summer                          sandtiger           1
#
# [174 rows x 5 columns]

# %%
by_shark_type.groupby(['Area','Season']).apply(lambda df: df.loc[df['Shark type'].idxmax()] )
# Out:
#                                                                                                                  Area  \
# Area                                               Season
# Eastern Cape Province                              northern_summer                              Eastern Cape Province
#                                                    northern_winter                              Eastern Cape Province
# KwaZulu-Natal                                      northern_summer                                      KwaZulu-Natal
#                                                    northern_winter                                      KwaZulu-Natal
# KwaZulu-Natal between Port Edward and Port St J... northern_summer  KwaZulu-Natal between Port Edward and Port St ...
# Transvaal                                          northern_summer                                          Transvaal
# Western Cape Province                              northern_summer                              Western Cape Province
#                                                    northern_winter                              Western Cape Province
# Western Province                                   northern_winter                                   Western Province
#
#                                                                     Area Total  \
# Area                                               Season
# Eastern Cape Province                              northern_summer       160.0
#                                                    northern_winter       160.0
# KwaZulu-Natal                                      northern_summer       213.0
#                                                    northern_winter       213.0
# KwaZulu-Natal between Port Edward and Port St J... northern_summer         1.0
# Transvaal                                          northern_summer         1.0
# Western Cape Province                              northern_summer       195.0
#                                                    northern_winter       195.0
# Western Province                                   northern_winter         5.0
#
#                                                                              Season  \
# Area                                               Season
# Eastern Cape Province                              northern_summer  northern_summer
#                                                    northern_winter  northern_winter
# KwaZulu-Natal                                      northern_summer  northern_summer
#                                                    northern_winter  northern_winter
# KwaZulu-Natal between Port Edward and Port St J... northern_summer  northern_summer
# Transvaal                                          northern_summer  northern_summer
# Western Cape Province                              northern_summer  northern_summer
#                                                    northern_winter  northern_winter
# Western Province                                   northern_winter  northern_winter
#
#                                                                                               level_3  \
# Area                                               Season
# Eastern Cape Province                              northern_summer                              white
#                                                    northern_winter                        raggedtooth
# KwaZulu-Natal                                      northern_summer                              white
#                                                    northern_winter                              white
# KwaZulu-Natal between Port Edward and Port St J... northern_summer  1.5 to 2.5 m [5' to 8.25'] copper
# Transvaal                                          northern_summer                          sandtiger
# Western Cape Province                              northern_summer                              white
#                                                    northern_winter                              white
# Western Province                                   northern_winter                              white
#
#                                                                     Shark type
# Area                                               Season
# Eastern Cape Province                              northern_summer          11
#                                                    northern_winter          18
# KwaZulu-Natal                                      northern_summer           4
#                                                    northern_winter          15
# KwaZulu-Natal between Port Edward and Port St J... northern_summer           1
# Transvaal                                          northern_summer           1
# Western Cape Province                              northern_summer          38
#                                                    northern_winter          36
# Western Province                                   northern_winter           1

# %%
by_shark_type.groupby(['Area']).apply(lambda df: df.loc[df['Shark type'].idxmax()] )
# Out:
#                                                                       Area  \
# Area
# New South Wales                                            New South Wales
# Northern Territory                                      Northern Territory
# Queensland                                                      Queensland
# Queensland                                                     Queensland
# South Australia                                            South Australia
# Tasmania                                                          Tasmania
# Territory of Cocos (Keeling) Islands  Territory of Cocos (Keeling) Islands
# Torres Strait                                                Torres Strait
# Torres Strait                                               Torres Strait
# Victoria                                                          Victoria
# Victoria                                                         Victoria
# Westerm Australia                                        Westerm Australia
# Western Australia                                        Western Australia
#
#                                       Area Total           Season  \
# Area
# New South Wales                            486.0  northern_winter
# Northern Territory                          23.0  northern_summer
# Queensland                                 311.0  northern_winter
# Queensland                                   1.0  northern_winter
# South Australia                            104.0  northern_winter
# Tasmania                                    41.0  northern_summer
# Territory of Cocos (Keeling) Islands         1.0  northern_summer
# Torres Strait                               70.0  northern_summer
# Torres Strait                                2.0  northern_summer
# Victoria                                    90.0  northern_winter
# Victoria                                     2.0  northern_winter
# Westerm Australia                            3.0  northern_summer
# Western Australia                          189.0  northern_winter
#
#                                                  level_3  Shark type
# Area
# New South Wales                                    white          23
# Northern Territory                    2 m [6.75'] copper           1
# Queensland                                          bull          11
# Queensland                                         tiger           1
# South Australia                                    white          14
# Tasmania                                           white           4
# Territory of Cocos (Keeling) Islands       bronze whaler           1
# Torres Strait                                      tiger           3
# Torres Strait                                      tiger           1
# Victoria                                           white           7
# Victoria                                           white           1
# Westerm Australia                                  white           1
# Western Australia                                  white          16
