# %%
import pandas as pd
import re
attacks = pd.read_csv("input/attacks.csv",encoding='utf-8')
attacks.Activity.value_counts().head(10)
# Out:
# Surfing         971
# Swimming        869
# Fishing         431
# Spearfishing    333
# Bathing         162
# Wading          149
# Diving          127
# Standing         99
# Snorkeling       89
# Scuba diving     76
# Name: Activity, dtype: int64

# %%
attacks['Country']= attacks['Country'].map(lambda x: x.replace('?',  "" ) if type(x)==str else x )

# %%
attacks['Country'].value_counts()[:50]
# Out:
# USA                     2229
# AUSTRALIA               1338
# SOUTH AFRICA             579
# PAPUA NEW GUINEA         134
# NEW ZEALAND              128
# BRAZIL                   112
# BAHAMAS                  109
# MEXICO                    89
# ITALY                     71
# FIJI                      62
# PHILIPPINES               61
# REUNION                   60
# NEW CALEDONIA             53
# CUBA                      46
# MOZAMBIQUE                45
# SPAIN                     44
# INDIA                     40
# EGYPT                     38
# JAPAN                     34
# CROATIA                   34
# PANAMA                    32
# SOLOMON ISLANDS           30
# IRAN                      29
# JAMAICA                   27
# GREECE                    25
# FRENCH POLYNESIA          25
# HONG KONG                 24
# ENGLAND                   23
# INDONESIA                 23
# COSTA RICA                17
# PACIFIC OCEAN             17
# ATLANTIC OCEAN            17
# BERMUDA                   16
# VIETNAM                   15
# TONGA                     15
# VANUATU                   14
# SRI LANKA                 14
# MARSHALL ISLANDS          13
# FRANCE                    13
# TURKEY                    12
# SOUTH ATLANTIC OCEAN      12
# IRAQ                      12
# CANADA                    12
# UNITED KINGDOM            11
# SENEGAL                   11
# VENEZUELA                 11
# NEW GUINEA                10
# MAURITIUS                 10
# KENYA                     10
# TAIWAN                     9
# Name: Country, dtype: int64

# %%
attacks['Area Total']=attacks['Area'].groupby(attacks['Area']).transform('count')

# %%
def get_month(date):
    try:
        
        month = re.findall(r'jan|feb|mar|apr|may|jun|jul|aug|sep|oct|nov|dec|summer|fall|', date, flags=re.IGNORECASE) 
        month =list(filter(None, month))
        if len(month):
            return month[0].lower()
        return None
    except TypeError:
        return None


attacks['Month']= attacks['Date'].map(get_month)

# %%
def get_season(month):
    northern_summer = ['apr','may','jun','jul','aug','sep','summer']
    northern_winter = ['jan','feb','mar','oct','nov','dec', 'fall']

    if month in northern_summer:
        return 'northern_summer'
    if month in northern_winter:
        return 'northern_winter'
    
attacks['Season']= attacks['Month'].map(get_season)

# %%
def get_data_by_country(df,country):
    return df[df['Country']==country]

# %%
def get_data_by_season(df,season):
    return df[df['Season']==season]

# %%
def fix_species_name(row):
    try:
        shark_type = re.search(r'^(.*) shark', row['Species '])
        if(shark_type):          
            return shark_type.group(1).lower()
    except TypeError as e:
        return row['Species ']
    return row['Species ']

# %%
attacks['Shark type']= attacks.apply(fix_species_name, axis='columns')

# %%
usa_attacks = get_data_by_country(attacks,'USA')

usa_attacks.groupby('Month')['Area'].count()
# Out:
# Month
# apr       157
# aug       325
# dec        64
# fall        3
# feb        57
# jan        51
# jul       358
# jun       243
# mar        97
# may       155
# nov       118
# oct       206
# sep       299
# summer      5
# Name: Area, dtype: int64

# %%
usa_attacks.groupby('Season')['Area'].count()
# Out:
# Season
# northern_summer    1542
# northern_winter     596
# Name: Area, dtype: int64

# %%
attacks[attacks['Fatal (Y/N)']=='Y'][['Shark type']].value_counts()
# Out:
# Shark type
# white                                                             98
# tiger                                                             60
# bull                                                              23
# 3.7 m [12']                                                       10
# 3 m [10']                                                          9
#                                                                   ..
# fishermen recovered partial remains from                           1
# galapagos                                                          1
# hand found in gut of 2.9 m to 3.3 m [9'7" to 10'11"] galapagos     1
# his hand was found in a 2.4 m [8'] tiger                           1
#  tiger                                                             1
# Length: 157, dtype: int64

# %%
attacks[attacks['Fatal (Y/N)']=='N'][['Shark type']].value_counts()
# Out:
# Shark type
# white                              324
# tiger                              169
# bull                               101
# bronze whaler                       53
# nurse                               49
#                                   ...
# 7.5'                                 1
# 70 kg                                1
# 76 cm [2.5'] carpet                  1
# 8' bull shark or caribbean reef      1
#  "gummy"                             1
# Length: 638, dtype: int64

# %%
attacks[attacks['Fatal (Y/N)']=='Y'][['Area']].value_counts()
# Out:
# Area
# New South Wales                  99
# Queensland                       75
# KwaZulu-Natal                    48
# Florida                          46
# Hawaii                           46
#                                  ..
# North of Pernambuco, Brazil       1
# Northern Bahamas                  1
# Northern Java                     1
# Northwest of Papua New Guinea     1
#  Manila Bay                       1
# Length: 400, dtype: int64

# %%
attacks[attacks['Fatal (Y/N)']=='N'][['Area']].value_counts()
# Out:
# Area
# Florida                918
# New South Wales        332
# California             242
# Hawaii                 213
# Queensland             207
#                       ...
# New Providence           1
# New Providence           1
# Norfolk                  1
# Norfolk Island           1
#  Kikori River mouth      1
# Length: 523, dtype: int64

# %%
usa_attacks.value_counts('Shark type').reset_index()
# Out:
#                           Shark type    0
# 0                              white  129
# 1                              tiger  102
# 2                               bull   46
# 3                                 4'   39
# 4                              nurse   38
# ..                               ...  ...
# 336                             7.5'    1
# 337  8' bull shark or caribbean reef    1
# 338              8' great hammerhead    1
# 339                        8' to 10'    1
# 340                         6' to 8'    1
#
# [341 rows x 2 columns]

# %%
def count_species(df):
        return df['Shark type'].value_counts()

# %%
attack_counts = attacks.groupby('Area').size().reset_index(name='counts').sort_values(by='counts',ascending=False)
attack_counts
# Out:
#                  Area  counts
# 263           Florida    1037
# 497   New South Wales     486
# 589        Queensland     311
# 315            Hawaii     298
# 158        California     290
# ..                ...     ...
# 326   Illeginni Atoll       1
# 327          Illinois       1
# 328  Imperia Province       1
# 329  In Convoy OB 274       1
# 412   Madeira Islands       1
#
# [825 rows x 2 columns]

# %%
usa_attacks_winter = get_data_by_season(usa_attacks, 'northern_winter')
usa_attacks_winter.value_counts('Shark type').reset_index()
# Out:
#           Shark type   0
# 0              tiger  53
# 1              white  43
# 2            spinner  10
# 3                 6'   9
# 4                 4'   9
# ..               ...  ..
# 132  7 m [23'] white   1
# 133         7' to 8'   1
# 134               8'   1
# 135        8' to 10'   1
# 136         6' to 8'   1
#
# [137 rows x 2 columns]

# %%
usa_attacks_summer = get_data_by_season(usa_attacks, 'northern_summer')
usa_attacks_summer.value_counts('Shark type').reset_index()
# Out:
#                           Shark type   0
# 0                              white  85
# 1                              tiger  47
# 2                               bull  41
# 3                                 4'  30
# 4                              nurse  29
# ..                               ...  ..
# 255  8' bull shark or caribbean reef   1
# 256                             7.5'   1
# 257                        7' female   1
# 258                              68"   1
# 259                         4m [13']   1
#
# [260 rows x 2 columns]

# %%
australia_attacks = get_data_by_country(attacks,'AUSTRALIA')
australia_attacks['Shark type'].value_counts()
# Out:
# white                                       108
# bronze whaler                                49
# tiger                                        46
# wobbegong                                    42
# grey nurse                                   33
#                                            ...
# 100-kg [221-lb] dead blue                     1
# "a very large                                 1
# 1.5 m [5'] "whaler                            1
# remains recovered from 5.5 m [18'] white      1
# 2 to 2.5 m                                    1
# Name: Shark type, Length: 208, dtype: int64

# %%
australia_attacks_summer = get_data_by_season(australia_attacks, 'northern_winter')
australia_attacks_summer.value_counts('Shark type').reset_index()
# Out:
#              Shark type   0
# 0                 white  65
# 1         bronze whaler  30
# 2                 tiger  28
# 3            grey nurse  26
# 4             wobbegong  25
# ..                  ...  ..
# 162           6 m [20']   1
# 163          5.5' to 6'   1
# 164   5.5 m [18'] white   1
# 165  5.5 m [18''] white   1
# 166             a small   1
#
# [167 rows x 2 columns]

# %%
australia_attacks_winter = get_data_by_season(australia_attacks, 'northern_summer')
australia_attacks_winter.value_counts('Shark type').reset_index()
# Out:
#                      Shark type   0
# 0                         white  41
# 1                 bronze whaler  19
# 2                         tiger  16
# 3                     wobbegong  15
# 4                    grey nurse   7
# ..                          ...  ..
# 77                         3+ m   1
# 78                           3'   1
# 79             3 m to 4 m white   1
# 80  3 m [10'], 270- kg [595-lb]   1
# 81                      "gummy"   1
#
# [82 rows x 2 columns]

# %%
 usa_attacks.groupby(['Area','Activity']).apply(count_species)
# Out:
# Area         Activity
# Alabama      Fishing                                6', 100-lb       1
#              Fishing                                bull             1
#              Fishing in Alabama Deep Fishing Rodeo  tiger            1
#              Swimming                               bull             1
#              Swimming                               bull             1
#                                                                     ..
# Virginia     Swimming                               sand             1
#              Swimming                               bull             1
# Wake Island  Spearfishing                           blacktip reef    1
# Washington   Surfing                                white            1
#              Surfing (lying prone on his board)     white            1
# Name: Shark type, Length: 812, dtype: int64

# %%
by_shark_type= usa_attacks.groupby(['Area','Area Total']).apply(count_species).reset_index().sort_values(by=["Area Total",'Shark type'],ascending=False)
by_shark_type
# Out:
#                        Area  Area Total        level_2  Shark type
# 89                  Florida      1037.0          nurse          35
# 90                  Florida      1037.0           bull          26
# 91                  Florida      1037.0             4'          21
# 92                  Florida      1037.0             3'          19
# 93                  Florida      1037.0     1.2 m [4']          17
# ..                      ...         ...            ...         ...
# 345                Missouri         1.0          nurse           1
# 363              New Mexico         1.0      sandtiger           1
# 374  North & South Carolina         1.0           blue           1
# 467         South Carolina          1.0     2.4 m [8']           1
# 500             Wake Island         1.0  blacktip reef           1
#
# [502 rows x 4 columns]

# %%
by_shark_type= usa_attacks.groupby(['Area','Area Total','Activity']).apply(count_species).reset_index().sort_values(by=["Area Total",'Shark type'],ascending=False)
by_shark_type[:50]
# Out:
#         Area  Area Total                                          Activity  \
# 323  Florida      1037.0                                           Surfing
# 324  Florida      1037.0                                           Surfing
# 325  Florida      1037.0                                           Surfing
# 326  Florida      1037.0                                           Surfing
# 327  Florida      1037.0                                           Surfing
# 328  Florida      1037.0                                           Surfing
# 329  Florida      1037.0                                           Surfing
# 330  Florida      1037.0                                           Surfing
# 395  Florida      1037.0                                          Swimming
# New Jersey        northern_summer           2
#                   northern_winter           1
# New Mexico        northern_winter           1
# New York          northern_summer           1
#                   northern_winter           1
# North Carolina    northern_summer           7
#                   northern_winter           1
# Oregon            northern_summer           6
#                   northern_winter           7
# Palmyra Atoll     northern_summer           1
# Puerto Rico       northern_summer           1
#                   northern_winter           1
# Rhode Island      northern_summer           1
# South Carolina    northern_summer           6
#                   northern_winter           1
# South Carolina    northern_summer           1
# Texas             northern_summer           4
#                   northern_winter           1
# US Virgin Islands northern_summer           1
#                   northern_winter           1
# Virginia          northern_summer           1
# Wake Island       northern_winter           1
# Washington        northern_summer           2

# %%
by_shark_type.groupby(['Area']).apply(lambda df: df.loc[df['Shark type'].idxmax()] )
# Out:
#                                                                       Area  \
# Area
# New South Wales                                            New South Wales
# Northern Territory                                      Northern Territory
# Queensland                                                      Queensland
# Queensland                                                     Queensland
# South Australia                                            South Australia
# Tasmania                                                          Tasmania
# Territory of Cocos (Keeling) Islands  Territory of Cocos (Keeling) Islands
# Torres Strait                                                Torres Strait
# Torres Strait                                               Torres Strait
# Victoria                                                          Victoria
# Victoria                                                         Victoria
# Westerm Australia                                        Westerm Australia
# Western Australia                                        Western Australia
#
#                                       Area Total           Season  \
# Area
# New South Wales                            486.0  northern_winter
# Northern Territory                          23.0  northern_summer
# Queensland                                 311.0  northern_winter
# Queensland                                   1.0  northern_winter
# South Australia                            104.0  northern_winter
# Tasmania                                    41.0  northern_summer
# Territory of Cocos (Keeling) Islands         1.0  northern_summer
# Torres Strait                               70.0  northern_summer
# Torres Strait                                2.0  northern_summer
# Victoria                                    90.0  northern_winter
# Victoria                                     2.0  northern_winter
# Westerm Australia                            3.0  northern_summer
# Western Australia                          189.0  northern_winter
#
#                                                  level_3  Shark type
# Area
# New South Wales                                    white          23
# Northern Territory                    2 m [6.75'] copper           1
# Queensland                                          bull          11
# Queensland                                         tiger           1
# South Australia                                    white          14
# Tasmania                                           white           4
# Territory of Cocos (Keeling) Islands       bronze whaler           1
# Torres Strait                                      tiger           3
# Torres Strait                                      tiger           1
# Victoria                                           white           7
# Victoria                                           white           1
# Westerm Australia                                  white           1
# Western Australia                                  white          16

# %%
by_shark_type= australia_attacks.groupby(['Area','Area Total','Season']).apply(count_species).reset_index().sort_values(by=["Area Total",'Shark type'],ascending=False)

by_shark_type[by_shark_type.Season=='northern_summer']
# Out:
#                                      Area  Area Total           Season  \
# 0                         New South Wales       486.0  northern_summer
# 1                         New South Wales       486.0  northern_summer
# 2                         New South Wales       486.0  northern_summer
# 3                         New South Wales       486.0  northern_summer
# 4                         New South Wales       486.0  northern_summer
# ..                                    ...         ...              ...
# 104                    Northern Territory        23.0  northern_summer
# 310                     Westerm Australia         3.0  northern_summer
# 311                     Westerm Australia         3.0  northern_summer
# 267                        Torres Strait          2.0  northern_summer
# 252  Territory of Cocos (Keeling) Islands         1.0  northern_summer
#
#            level_3  Shark type
# 0        wobbegong          11
# 1            white          10
# 2    bronze whaler           7
# 3       grey nurse           3
# 4               6'           3
# ..             ...         ...
# 104  bronze whaler           1
# 310    tawny nurse           1
# 311          white           1
# 267          tiger           1
# 252  bronze whaler           1
#
# [120 rows x 5 columns]
