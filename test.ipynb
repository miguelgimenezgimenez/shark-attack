# %%
import pandas as pd
import re
attacks = pd.read_csv("input/attacks.csv",encoding='utf-8')
attacks.Activity.value_counts().head(10)
# Out:
# Surfing         971
# Swimming        869
# Fishing         431
# Spearfishing    333
# Bathing         162
# Wading          149
# Diving          127
# Standing         99
# Snorkeling       89
# Scuba diving     76
# Name: Activity, dtype: int64

# %%
attacks['Country']= attacks['Country'].map(lambda x: x.replace('?',  "" ) if type(x)==str else x )

# %%
attacks['Country'].value_counts()[:50]
# Out:
# USA                     2229
# AUSTRALIA               1338
# SOUTH AFRICA             579
# PAPUA NEW GUINEA         134
# NEW ZEALAND              128
# BRAZIL                   112
# BAHAMAS                  109
# MEXICO                    89
# ITALY                     71
# FIJI                      62
# PHILIPPINES               61
# REUNION                   60
# NEW CALEDONIA             53
# CUBA                      46
# MOZAMBIQUE                45
# SPAIN                     44
# INDIA                     40
# EGYPT                     38
# JAPAN                     34
# CROATIA                   34
# PANAMA                    32
# SOLOMON ISLANDS           30
# IRAN                      29
# JAMAICA                   27
# GREECE                    25
# FRENCH POLYNESIA          25
# HONG KONG                 24
# ENGLAND                   23
# INDONESIA                 23
# COSTA RICA                17
# PACIFIC OCEAN             17
# ATLANTIC OCEAN            17
# BERMUDA                   16
# VIETNAM                   15
# TONGA                     15
# VANUATU                   14
# SRI LANKA                 14
# MARSHALL ISLANDS          13
# FRANCE                    13
# SOUTH ATLANTIC OCEAN      12
# TURKEY                    12
# CANADA                    12
# IRAQ                      12
# UNITED KINGDOM            11
# SENEGAL                   11
# VENEZUELA                 11
# NEW GUINEA                10
# MAURITIUS                 10
# KENYA                     10
# ECUADOR                    9
# Name: Country, dtype: int64

# %%
attacks['Area Total']=attacks['Area'].groupby(attacks['Area']).transform('count')

# %%
def get_month(date):
    try:
        
        month = re.findall(r'jan|feb|mar|apr|may|jun|jul|aug|sep|oct|nov|dec|summer|fall|', date, flags=re.IGNORECASE) 
        month =list(filter(None, month))
        if len(month):
            return month[0].lower()
        return None
    except TypeError:
        return None


attacks['Month']= attacks['Date'].map(get_month)

# %%
def get_season(month):
    northern_summer = ['apr','may','jun','jul','aug','sep','summer']
    northern_winter = ['jan','feb','mar','oct','nov','dec', 'fall']

    if month in northern_summer:
        return 'northern_summer'
    if month in northern_winter:
        return 'northern_winter'
    
attacks['Season']= attacks['Month'].map(get_season)

# %%
def get_data_by_country(df,country):
    return df[df['Country']==country]

# %%
def get_data_by_season(df,season):
    return df[df['Season']==season]

# %%
def fix_species_name(row):
    try:
        shark_type = re.search(r'^(.*) shark', row['Species '])
        if(shark_type):          
            return shark_type.group(1).lower()
    except TypeError as e:
        return row['Species ']
    return row['Species ']

# %%
attacks['Shark type']= attacks.apply(fix_species_name, axis='columns')

# %%
usa_attacks = get_data_by_country(attacks,'USA')

usa_attacks.groupby('Month')['Area'].count()
# Out:
# Month
# apr       157
# aug       325
# dec        64
# fall        3
# feb        57
# jan        51
# jul       358
# jun       243
# mar        97
# may       155
# nov       118
# oct       206
# sep       299
# summer      5
# Name: Area, dtype: int64

# %%
usa_attacks.groupby('Season')['Area'].count()
# Out:
# Season
# northern_summer    1542
# northern_winter     596
# Name: Area, dtype: int64

# %%
attacks[attacks['Fatal (Y/N)']=='Y'][['Shark type']].value_counts()
# Out:
# Shark type
# white                                                           98
# tiger                                                           60
# bull                                                            23
# 3.7 m [12']                                                     10
# 3 m [10']                                                        9
#                                                                 ..
# Sharks averaged 1.8 m [6'] in length                             1
# Shark involvement probable                                       1
# Shark involvement prior to death was not confirmed               1
# Shark involvement prior to death suspected but not confirmed     1
#                                                                  1
# Length: 173, dtype: int64

# %%
attacks[attacks['Fatal (Y/N)']=='N'][['Shark type']].value_counts()
# Out:
# Shark type
# white                                      324
# tiger                                      169
# bull                                       101
# bronze whaler                               53
# nurse                                       49
#                                           ...
# 6' blacktip                                  1
# 6' shark, possibly a blactip or spinner      1
# 6' to 7'                                     1
# 6' to 7' blacktip                            1
# �small brown                                 1
# Length: 693, dtype: int64

# %%
# Out:
# Area
# New South Wales                  99
# Queensland                       75
# KwaZulu-Natal                    48
# Florida                          46
# Hawaii                           46
#                                  ..
# North of Pernambuco, Brazil       1
# Northern Bahamas                  1
# Northern Java                     1
# Northwest of Papua New Guinea     1
#  Manila Bay                       1
# Length: 400, dtype: int64

# %%
attacks[attacks['Fatal (Y/N)']=='N'][['Area']].value_counts()
# Out:
# Area
# Florida                918
# New South Wales        332
# California             242
# Hawaii                 213
# Queensland             207
#                       ...
# New Providence           1
# New Providence           1
# Norfolk                  1
# Norfolk Island           1
#  Kikori River mouth      1
# Length: 523, dtype: int64

# %%
usa_attacks.value_counts('Shark type').reset_index()
# Out:
#                           Shark type    0
# 0                              white  129
# 1                              tiger  102
# 2    Shark involvement not confirmed   53
# 3                               bull   46
# 4                                 4'   39
# ..                               ...  ...
# 377                         5' to 8'    1
# 378                         5' to 7'    1
# 379         5' to 6' spinner or bull    1
# 380     possibly a juvenile blacktip    1
# 381                     �small brown    1
#
# [382 rows x 2 columns]

# %%
def count_species(df):
        return df['Shark type'].value_counts()

# %%
attack_counts = attacks.groupby('Area').size().reset_index(name='counts').sort_values(by='counts',ascending=False)
attack_counts
# Out:
#                  Area  counts
# 263           Florida    1037
# 497   New South Wales     486
# 589        Queensland     311
# 315            Hawaii     298
# 158        California     290
# ..                ...     ...
# 326   Illeginni Atoll       1
# 327          Illinois       1
# 328  Imperia Province       1
# 329  In Convoy OB 274       1
# 412   Madeira Islands       1
#
# [825 rows x 2 columns]

# %%
usa_attacks_winter = get_data_by_season(usa_attacks, 'northern_winter')
usa_attacks_winter.value_counts('Shark type').reset_index()
# Out:
#                                             Shark type   0
# 0                                                tiger  53
# 1                                                white  43
# 2                      Shark involvement not confirmed  13
# 3    Shark involvement prior to death was not confi...  11
# 4                                              spinner  10
# ..                                                 ...  ..
# 146                                        >2.4 m [8']   1
# 147                                   >6 m [20'] white   1
# 148                                      >6.7 m [22']    1
# 149                      C. maculpinnis or C. limbatus   1
# 150                                           6' to 8'   1
#
# [151 rows x 2 columns]

# %%
usa_attacks_summer = get_data_by_season(usa_attacks, 'northern_summer')
usa_attacks_summer.value_counts('Shark type').reset_index()
# Out:
#                            Shark type   0
# 0                               white  85
# 1                               tiger  47
# 2                                bull  41
# 3     Shark involvement not confirmed  39
# 4                                  4'  30
# ..                                ...  ..
# 287                              9.5'   1
# 288                            9-foot   1
# 289                        9'2" white   1
# 290                                9'   1
# 291  5.5 m to 6 m [18' to 20']  white   1
#
# [292 rows x 2 columns]

# %%
australia_attacks = get_data_by_country(attacks,'AUSTRALIA')
australia_attacks['Shark type'].value_counts()
# Out:
# white                                     108
# bronze whaler                              49
# tiger                                      46
# wobbegong                                  42
# grey nurse                                 33
#                                          ...
# 2' to 3'                                    1
# 1.8 m to 2.4 m  [6' to 8']                  1
# 3.7 m to 4.3 m [12' to 14']                 1
# thought to involve a >2 m [6.75'] bull      1
# 2.7 m  [9']                                 1
# Name: Shark type, Length: 239, dtype: int64

# %%
australia_attacks_summer = get_data_by_season(australia_attacks, 'northern_winter')
australia_attacks_summer.value_counts('Shark type').reset_index()
# Out:
#               Shark type   0
# 0                  white  65
# 1          bronze whaler  30
# 2                  tiger  28
# 3             grey nurse  26
# 4              wobbegong  25
# ..                   ...  ..
# 182    Blue pointer, 12'   1
# 183         Blue pointer   1
# 184  76 cm [2.5'] carpet   1
# 185               7-gill   1
# 186              a small   1
#
# [187 rows x 2 columns]

# %%
australia_attacks_winter = get_data_by_season(australia_attacks, 'northern_summer')
australia_attacks_winter.value_counts('Shark type').reset_index()
# Out:
#                                            Shark type   0
# 0                                               white  41
# 1                                       bronze whaler  19
# 2                                               tiger  16
# 3                                           wobbegong  15
# 4                                             Invalid   8
# ..                                                ...  ..
# 94  Shark involvement not confirmed; thought to be...   1
# 95     Shark involvement prior to death not confirmed   1
# 96  Shark involvement prior to death suspected but...   1
# 97  Shark seen feeding on turtle scraps thrown ove...   1
# 98                                            "gummy"   1
#
# [99 rows x 2 columns]

# %%
 usa_attacks.groupby(['Area','Activity']).apply(count_species)
# Out:
# Area         Activity
# Alabama      Fishing                                6', 100-lb       1
#              Fishing                                bull             1
#              Fishing in Alabama Deep Fishing Rodeo  tiger            1
#              Swimming                               bull             1
#              Swimming                               bull             1
#                                                                     ..
# Virginia     Swimming                               sand             1
#              Swimming                               bull             1
# Wake Island  Spearfishing                           blacktip reef    1
# Washington   Surfing                                white            1
#              Surfing (lying prone on his board)     white            1
# Name: Shark type, Length: 954, dtype: int64

# %%
by_shark_type= usa_attacks.groupby(['Area','Area Total']).apply(count_species).reset_index().sort_values(by=["Area Total",'Shark type'],ascending=False)
by_shark_type
# Out:
#                        Area  Area Total                          level_2  \
# 104                 Florida      1037.0                            nurse
# 105                 Florida      1037.0                             bull
# 106                 Florida      1037.0  Shark involvement not confirmed
# 107                 Florida      1037.0                               4'
# 108                 Florida      1037.0                               3'
# ..                      ...         ...                              ...
# 400                Missouri         1.0                            nurse
# 420              New Mexico         1.0                        sandtiger
# 437  North & South Carolina         1.0                             blue
# 542         South Carolina          1.0                       2.4 m [8']
# 582             Wake Island         1.0                    blacktip reef
#
#      Shark type
# 104          35
# 105          26
# 106          23
# 107          21
# 108          19
# ..          ...
# 400           1
# 420           1
# 437           1
# 542           1
# 582           1
#
# [584 rows x 4 columns]

# %%
by_shark_type= usa_attacks.groupby(['Area','Area Total']).apply(count_species).reset_index().sort_values(by=["Area Total",'Shark type'],ascending=False)
by_shark_type[:50]
# Out:
#         Area  Area Total                                            level_2  \
# 104  Florida      1037.0                                              nurse
# 105  Florida      1037.0                                               bull
# 106  Florida      1037.0                    Shark involvement not confirmed
# 107  Florida      1037.0                                                 4'
# 108  Florida      1037.0                                                 3'
# 109  Florida      1037.0                                         1.2 m [4']
# 110  Florida      1037.0                                           blacktip
# 111  Florida      1037.0                                           4' to 5'
# 112  Florida      1037.0                                                 6'
# 113  Florida      1037.0                                            Invalid
# 114  Florida      1037.0                                              lemon
# 115  Florida      1037.0                                         1.8 m [6']
# 116  Florida      1037.0                                              tiger
# 117  Florida      1037.0                                            spinner
# 118  Florida      1037.0                                                 5'
# 119  Florida      1037.0                                           3' to 4'
# 120  Florida      1037.0                                blacktip or spinner
# 121  Florida      1037.0  Shark involvement prior to death was not confi...
# 122  Florida      1037.0                                         1.5 m [5']
# 123  Florida      1037.0                                         hammerhead
# 124  Florida      1037.0                          1.2 m to 1.5 m [4' to 5']
# 125  Florida      1037.0                               Unidentified species
# 126  Florida      1037.0                                           "a small
# 127  Florida      1037.0                              Questionable incident
# 128  Florida      1037.0                                            a small
# 129  Florida      1037.0            possibly a juvenile blacktip or spinner
# 130  Florida      1037.0                                           2' to 3'
# 131  Florida      1037.0                                             "small
# 132  Florida      1037.0                                1.8 m [6'] blacktip
# 133  Florida      1037.0       Shark involvement prior to death unconfirmed
# 134  Florida      1037.0                                           5' to 6'
# 135  Florida      1037.0                          1.8 m to 2.4 m [6' to 8']
# 136  Florida      1037.0                                     3 m [10'] bull
# 137  Florida      1037.0                                         3.5' to 4'
# 138  Florida      1037.0                                              white
# 139  Florida      1037.0                                                 no
# 140  Florida      1037.0                          0.9 m to 1.2 m [3' to 4']
# 141  Florida      1037.0                                         0.9 m [3']
# 142  Florida      1037.0                                           4' to 6'
# 143  Florida      1037.0                                    possibly a bull
# 144  Florida      1037.0                                           juvenile
# 145  Florida      1037.0                                               4.5'
# 146  Florida      1037.0                                           3' to 5'
# 147  Florida      1037.0                                 possibly a spinner
# 148  Florida      1037.0                          1.5 m to 1.8 m [5' to 6']
# 149  Florida      1037.0                                               mako
# 150  Florida      1037.0                                     small blacktip
# 151  Florida      1037.0                                         2.4 m [8']
# 152  Florida      1037.0                                        small nurse
# 153  Florida      1037.0                                           6' to 8'
#
#      Shark type
# 104          35
# 105          26
# 106          23
# 107          21
# 108          19
# 109          17
# 110          15
# 111          15
# 112          15
# 113          14
# 114          14
# 115          13
# 116          13
# 117          12
# 118          12
# 119          11
# 120          10
# 121          10
# 122          10
# 123           9
# 124           9
# 125           6
# 126           6
# 127           5
# 128           5
# 129           5
# 130           4
# 131           4
# 132           4
# 133           4
# 134           4
# 135           4
# 136           3
# 137           3
# 138           3
# 139           3
# 140           3
# 141           3
# 142           3
# 143           3
# 144           3
# 145           2
# 146           2
# 147           2
# 148           2
# 149           2
# 150           2
# 151           2
# 152           2
# 153           2

# %%
by_shark_type[by_shark_type.Season=='northern_winter']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-e0e3a4a2da2b> in <module>
# ----> 1 by_shark_type[by_shark_type.Season=='northern_winter']
#
# /opt/anaconda3/envs/virtual_workspace/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Season'

# %%
by_shark_type.groupby(['Area']).apply(lambda df: df.loc[df['Shark type'].idxmax()] )

# %%
by_shark_type.groupby(['Area']).apply(lambda df: df.loc[df['Shark type'].idxmax()] )

# %%
by_shark_type= australia_attacks.groupby(['Area','Area Total','Season']).apply(count_species).reset_index().sort_values(by=["Area Total",'Shark type'],ascending=False)

by_shark_type[by_shark_type.Season=='northern_summer']
